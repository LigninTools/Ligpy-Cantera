# %%
import pandas as pd

# %%
rxn = pd.read_csv('cti_rxn.txt', header = None)
AnE = pd.read_csv('complete_rateconstant_list.txt', header = None)
AnE_list = AnE.values.tolist()
rxn_list = rxn.values.tolist()

# %%
AnE_list[333][0]
# Out:
# '1*10**8 0 46046-4186'

# %%
rxn.head()
# Out:
#                                 0
# 0                 PLIGH => PRLIGH
# 1     LIGH => C3H6 + OH + RLIGM2A
# 2    LIGM2 => RPHENOXM2 + RADIOM2
# 3  PLIGM2 => RPHENOXM2 + PRADIOM2
# 4          LIG => RPHENOX + RADIO

# %%
df = pd.DataFrame()
temp_list = []
for rxn in rxn_list:
    for i in range(406):
        content = "reaction" + '(' + "'" + rxn[0] + "'" + ', ' + '[' + AnE_list[i][0] + ']' + ')'
        temp_list.append(content)
        
    
df['rxn_list'] = temp_list
#df['AnE'] = AnE_list
df.head()
# Out:
#                                            rxn_list
# 0  reaction('PLIGH => PRLIGH', [1.00E+13 0 163254])
# 1  reaction('PLIGH => PRLIGH', [1.00E+13 0 163254])
# 2  reaction('PLIGH => PRLIGH', [1.00E+13 0 163254])
# 3  reaction('PLIGH => PRLIGH', [1.00E+13 0 163254])
# 4  reaction('PLIGH => PRLIGH', [1.00E+13 0 184184])

# %%
reaction_list = []
for i in range(406):
    reaction_list.append('# Reaction' + str(i+1))

reaction_list = pd.DataFrame(reaction_list)
df['rxnnumber'] = reaction_list
df = df[['rxnnumber', 'rxn_list']]
dff = df.stack().reset_index(level = [0,1], drop=True)

# %%
dfff = pd.DataFrame(dff)
dfff.to_csv('cti_complete_reaction_list_final', index=False)

# %%
dfff
# Out:
#                                                         0
# 0                                             # Reaction1
# 1        reaction('PLIGH => PRLIGH', [1.00E+13 0 163254])
# 2                                             # Reaction2
# 3        reaction('PLIGH => PRLIGH', [1.00E+13 0 163254])
# 4                                             # Reaction3
# 5        reaction('PLIGH => PRLIGH', [1.00E+13 0 163254])
# 6                                             # Reaction4
# 7        reaction('PLIGH => PRLIGH', [1.00E+13 0 163254])
# 8                                             # Reaction5
# 9        reaction('PLIGH => PRLIGH', [1.00E+13 0 184184])
# 10                                            # Reaction6
# 11       reaction('PLIGH => PRLIGH', [1.00E+13 0 188370])
# 12                                            # Reaction7
# 13       reaction('PLIGH => PRLIGH', [1.00E+13 0 171626])
# 14                                            # Reaction8
# 15       reaction('PLIGH => PRLIGH', [1.00E+13 0 179998])
# 16                                            # Reaction9
# 17       reaction('PLIGH => PRLIGH', [1.00E+13 0 167440])
# 18                                           # Reaction10
# 19       reaction('PLIGH => PRLIGH', [1.00E+13 0 121394])
# 20                                           # Reaction11
# 21       reaction('PLIGH => PRLIGH', [4.00E+10 0 209300])
# 22                                           # Reaction12
# 23       reaction('PLIGH => PRLIGH', [4.00E+10 0 209300])
# 24                                           # Reaction13
# 25       reaction('PLIGH => PRLIGH', [1.00E+13 0 133952])
# 26                                           # Reaction14
# 27       reaction('PLIGH => PRLIGH', [1.00E+13 0 133952])
# 28                                           # Reaction15
# 29       reaction('PLIGH => PRLIGH', [1.00E+13 0 133952])
# ...                                                   ...
# 165212  reaction('RADIO + KET => ADIO + RKET', [1*10**...
# 165213  reaction('RADIO + KET => ADIO + RKET', [1*10**...
# 165214  reaction('RADIO + KET => ADIO + RKET', [1*10**...
# 165215  reaction('RADIO + KET => ADIO + RKET', [1*10**...
# 165216  reaction('RADIO + KET => ADIO + RKET', [1*10**...
# 165217  reaction('RADIO + KET => ADIO + RKET', [1*10**...
# 165218  reaction('RADIO + KET => ADIO + RKET', [1*10**...
# 165219  reaction('RADIO + KET => ADIO + RKET', [1*10**...
# 165220  reaction('RADIO + KET => ADIO + RKET', [1*10**...
# 165221  reaction('RADIO + KET => ADIO + RKET', [1*10**...
# 165222  reaction('RADIO + KET => ADIO + RKET', [1*10**...
# 165223  reaction('RADIO + KET => ADIO + RKET', [1*10**...
# 165224  reaction('RADIO + KET => ADIO + RKET', [1*10**...
# 165225  reaction('RADIO + KET => ADIO + RKET', [1*10**...
# 165226  reaction('RADIO + KET => ADIO + RKET', [1*10**...
# 165227  reaction('RADIO + KET => ADIO + RKET', [1*10**...
# 165228  reaction('RADIO + KET => ADIO + RKET', [1*10**...
# 165229  reaction('RADIO + KET => ADIO + RKET', [1*10**...
# 165230  reaction('RADIO + KET => ADIO + RKET', [1*10**...
# 165231  reaction('RADIO + KET => ADIO + RKET', [1*10**...
# 165232  reaction('RADIO + KET => ADIO + RKET', [1*10**...
# 165233  reaction('RADIO + KET => ADIO + RKET', [1*10**...
# 165234  reaction('RADIO + KET => ADIO + RKET', [1*10**...
# 165235  reaction('RADIO + KET => ADIO + RKET', [1*10**...
# 165236  reaction('RADIO + KET => ADIO + RKET', [1*10**...
# 165237  reaction('RADIO + KET => ADIO + RKET', [1*10**...
# 165238  reaction('RADIO + KET => ADIO + RKET', [1*10**...
# 165239  reaction('RADIO + KET => ADIO + RKET', [1*10**...
# 165240  reaction('RADIO + KET => ADIO + RKET', [1*10**...
# 165241  reaction('RADIO + KET => ADIO + RKET', [1*10**...
#
# [165242 rows x 1 columns]
