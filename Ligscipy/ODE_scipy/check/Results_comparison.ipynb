# %% [markdown]
# `sol.dat`: vode solver,
# <p>`sol_check.dat`: LSODA(odenit),
# <p>`ddasac_results_1.out` : DDASAC,
# <p>`model.c`: species order(result order) which is different from ours is included in this file.
# <p>Please make a dataframe, species as rows, solvers as columns, and %error comparing to ddasac’s result.

# %%
import pandas as pd
import numpy as np

# %%
#for VODE and LSODA
species_list = ['time','T', 'ADIO', 'ADIOM2', 'ALD3', 'C10H2', 'C10H2M2', 'C10H2M4', 'C2H6', 'C3H4O', 'C3H4O2', 'C3H6', 'C3H6O2', 'C3H8O2', 
                'CH2CO', 'CH3CHO', 'CH3OH', 'CH4', 'CHAR', 'CO', 'CO2', 'COUMARYL', 'ETOH', 'H2', 'H2O', 'KET', 'KETD', 'KETDM2', 'KETM2', 
                'LIG', 'LIGC', 'LIGH', 'LIGM2', 'LIGO', 'MGUAI', 'OH', 'PADIO', 'PADIOM2', 'PC2H2', 'PCH2OH', 'PCH2P', 'PCH3', 'PCHO', 
                'PCHOHP', 'PCHP2', 'PCOH', 'PCOHP2', 'PCOS', 'PFET3', 'PFET3M2', 'PH2', 'PHENOL', 'PKETM2', 'PLIG', 'PLIGC', 'PLIGH', 
                'PLIGM2', 'PLIGO', 'PRADIO', 'PRADIOM2', 'PRFET3', 'PRFET3M2', 'PRKETM2', 'PRLIGH', 'PRLIGH2', 'PRLIGM2A', 'RADIO', 
                'RADIOM2', 'RC3H3O', 'RC3H5O2', 'RC3H7O2', 'RCH3', 'RCH3O', 'RKET', 'RKETM2', 'RLIGA', 'RLIGB', 'RLIGH', 'RLIGM2A', 
                'RLIGM2B', 'RMGUAI', 'RPHENOL', 'RPHENOX', 'RPHENOXM2', 'SYNAPYL', 'VADIO', 'VADIOM2', 'VCOUMARYL', 'VKET', 'VKETD', 
                'VKETDM2', 'VKETM2', 'VMGUAI', 'VPHENOL', 'VSYNAPYL']

# %%
vode_file = pd.read_csv('sol.dat',delim_whitespace = True, header = None)
vode_results = list(vode_file.iloc[-2])
vode_file_new = pd.read_csv('sol_new.dat',delim_whitespace = True, header = None)
vode_results_new = list(vode_file_new.iloc[-2])
LSODA_file = pd.read_csv('sol_check.dat',delim_whitespace = True, header = None)
LSODA_results = list(LSODA_file.iloc[175])

# %%
results = pd.DataFrame({'species':species_list,'VODE':vode_results,'VODE_new':vode_results_new,'LSODA':LSODA_results}).drop([0,1]).sort_values('species').reset_index(drop=True)

# %%
results.LSODA[abs(results.LSODA) < 1e-11] = 1e-11
results.VODE[abs(results.VODE) < 1e-11] = 1e-11
results.VODE_new[abs(results.VODE_new) < 1e-11] = 1e-11
results
# Out:
# C:\Users\Jiayuan\Miniconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\Users\Jiayuan\Miniconda3\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# C:\Users\Jiayuan\Miniconda3\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
#            LSODA          VODE      VODE_new    species
# 0   1.000000e-11  1.000000e-11  1.000000e-11       ADIO
# 1   1.000000e-11  1.000000e-11  1.000000e-11     ADIOM2
# 2   3.968274e-01  3.968274e-01  3.968274e-01       ALD3
# 3   5.394858e-04  5.394859e-04  5.394859e-04      C10H2
# 4   3.744611e-03  3.744613e-03  3.744612e-03    C10H2M2
# 5   2.716637e-02  2.716638e-02  2.716638e-02    C10H2M4
# 6   2.071977e-02  2.071977e-02  2.071977e-02       C2H6
# 87  1.801577e-02  1.801577e-02  1.801577e-02      VKETD
# 88  2.610817e-01  2.610818e-01  2.610818e-01    VKETDM2
# 89  3.595380e-05  3.595380e-05  3.595380e-05     VKETM2
# 90  7.342253e-03  7.342254e-03  7.342254e-03     VMGUAI
# 91  9.997323e-02  9.997328e-02  9.997327e-02    VPHENOL
# 92  4.562040e-02  4.562041e-02  4.562041e-02   VSYNAPYL
#
# [93 rows x 4 columns]

# %%
#for ddasac
species_ddasac = ['PLIGC', 'PLIGH', 'PLIGO', 'PRLIGH', 'LIGH', 'C3H6', 'OH', 'RLIGM2A', 'LIGM2',
      'RPHENOXM2', 'RADIOM2', 'PLIGM2', 'PRADIOM2', 'LIG', 'RPHENOX', 'RADIO', 'PLIG', 'PRADIO',
      'PADIOM2', 'PADIO', 'PKETM2', 'PRKETM2', 'KETDM2', 'CO', 'C10H2M4', 'H2', 'C10H2', 'RLIGH',
      'ALD3', 'PRLIGH2', 'PRLIGM2A', 'RMGUAI', 'C3H6O2', 'KETM2', 'RLIGM2B', 'PFET3M2',
      'PRFET3M2', 'C3H4O2', 'RPHENOL',' RLIGA', 'KET', 'RLIGB', 'PFET3', 'PRFET3', 'SYNAPYL',
      'RKETM2', 'COUMARYL', 'RKET', 'KETD', 'RC3H7O2', 'RCH3O', 'CH3CHO', 'C10H2M2', 'CH2CO',
      'CO2', 'ADIOM2', 'PH2', 'PCOH', 'RC3H5O2', 'RC3H3O', 'PCOS', 'ADIO', 'RCH3', 'PCH3', 'ETOH',
      'H2O', 'PCH2OH', 'PCHP2', 'PCHOHP', 'CHAR', 'PCOHP2', 'PC2H2', 'PCHO', 'CH3OH', 'C2H6',
      'PCH2P', 'VADIOM2', 'VKETM2', 'VKETDM2', 'VSYNAPYL', 'MGUAI', 'VMGUAI', 'VCOUMARYL',
      'VADIO', 'VKET', 'VKETD', 'PHENOL', 'VPHENOL', 'LIGC', 'LIGO', 'C3H8O2', 'CH4', 'C3H4O']

# %%
ddasac_file = pd.read_csv('ddasac_results_1.out',delim_whitespace = True, header = None)
ddasac_df = list(ddasac_file.iloc[37])[2:95]

# %%
ddasac = pd.DataFrame({'name':species_ddasac,'ddasac':ddasac_df}).sort_values('name').reset_index(drop=True)

# %%
#???why RLIGA is on the top????
ddasac
# Out:
#          ddasac       name
# 0    1.6772e-08      RLIGA
# 1   9.55351e-16       ADIO
# 2   1.08143e-32     ADIOM2
# 3      0.396697       ALD3
# 4   0.000551251      C10H2
# 5    0.00228165    C10H2M2
# 6     0.0374022    C10H2M4
# 7     0.0192449       C2H6
# 8   0.000535437      C3H4O
# 9      0.165187     C3H4O2
# 10    0.0524898       C3H6
# 11    0.0200774     C3H6O2
# 12  0.000227315     C3H8O2
# 13      1.41697      CH2CO
# 14     0.182685     CH3CHO
# 15     0.601829      CH3OH
# 16    0.0308495        CH4
# 17      1.43249       CHAR
# 18    0.0797251         CO
# 19     0.448259        CO2
# 20    0.0156674   COUMARYL
# 21    0.0533126       ETOH
# 22      3.10498         H2
# 23      2.41695        H2O
# 24  3.42118e-08        KET
# 25     0.780974       KETD
# 26    0.0414782     KETDM2
# 27 -1.28666e-27      KETM2
# 28  3.41953e-08        LIG
# 29  0.000247643       LIGC
# ..          ...        ...
# 63 -7.35759e-28    PRLIGH2
# 64 -1.82806e-28   PRLIGM2A
# 65  4.80498e-12      RADIO
# 66 -5.35339e-31    RADIOM2
# 67  5.68238e-06     RC3H3O
# 68  3.97417e-09    RC3H5O2
# 69  1.40443e-22    RC3H7O2
# 70  4.24985e-06       RCH3
# 71  2.31664e-05      RCH3O
# 72  1.12377e-08       RKET
# 73  2.32318e-28     RKETM2
# 74  8.34995e-07      RLIGB
# 75  -7.2107e-29      RLIGH
# 76  2.05673e-25    RLIGM2A
# 77   1.6046e-26    RLIGM2B
# 78 -2.46924e-24     RMGUAI
# 79  5.40515e-05    RPHENOL
# 80   0.00399654    RPHENOX
# 81 -2.81762e-25  RPHENOXM2
# 82    0.0320214    SYNAPYL
# 83  5.69569e-06      VADIO
# 84  0.000519515    VADIOM2
# 85   0.00044665  VCOUMARYL
# 86   0.00212812       VKET
# 87    0.0205886      VKETD
# 88      0.30757    VKETDM2
# 89  3.84654e-05     VKETM2
# 90    0.0074192     VMGUAI
# 91    0.0731682    VPHENOL
# 92    0.0660381   VSYNAPYL
#
# [93 rows x 2 columns]

# %%
# modify the order of species
ddasac_1 = ddasac.iloc[0]
ddasac_2 = ddasac.iloc[1:74]
ddasac_3 = ddasac.iloc[74:]
ddasac_resort = ddasac_2.append(ddasac_1).append(ddasac_3).reset_index(drop=True)
#abtol=1e-11
ddasac_resort['ddasac'] = ddasac_resort['ddasac'].astype(float)
ddasac_resort.ddasac[abs(ddasac_resort.ddasac) < 1e-11] = 1e-11
# Out:
# C:\Users\Jiayuan\Miniconda3\lib\site-packages\ipykernel\__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
ddasac_resort
# Out:
#           ddasac       name
# 0   1.000000e-11       ADIO
# 1   1.000000e-11     ADIOM2
# 2   3.966974e-01       ALD3
# 3   5.512506e-04      C10H2
# 4   2.281646e-03    C10H2M2
# 5   3.740217e-02    C10H2M4
# 6   1.924486e-02       C2H6
# 7   5.354366e-04      C3H4O
# 8   1.651874e-01     C3H4O2
# 9   5.248976e-02       C3H6
# 10  2.007737e-02     C3H6O2
# 11  2.273146e-04     C3H8O2
# 12  1.416971e+00      CH2CO
# 13  1.826846e-01     CH3CHO
# 14  6.018294e-01      CH3OH
# 15  3.084947e-02        CH4
# 16  1.432492e+00       CHAR
# 17  7.972507e-02         CO
# 18  4.482589e-01        CO2
# 19  1.566738e-02   COUMARYL
# 20  5.331256e-02       ETOH
# 21  3.104976e+00         H2
# 22  2.416953e+00        H2O
# 23  3.421181e-08        KET
# 24  7.809741e-01       KETD
# 25  4.147822e-02     KETDM2
# 26  1.000000e-11      KETM2
# 27  3.419535e-08        LIG
# 28  2.476434e-04       LIGC
# 29  1.000000e-11       LIGH
# ..           ...        ...
# 63  1.000000e-11   PRLIGM2A
# 64  1.000000e-11      RADIO
# 65  1.000000e-11    RADIOM2
# 66  5.682383e-06     RC3H3O
# 67  3.974174e-09    RC3H5O2
# 68  1.000000e-11    RC3H7O2
# 69  4.249850e-06       RCH3
# 70  2.316644e-05      RCH3O
# 71  1.123766e-08       RKET
# 72  1.000000e-11     RKETM2
# 73  1.677205e-08      RLIGA
# 74  8.349950e-07      RLIGB
# 75  1.000000e-11      RLIGH
# 76  1.000000e-11    RLIGM2A
# 77  1.000000e-11    RLIGM2B
# 78  1.000000e-11     RMGUAI
# 79  5.405155e-05    RPHENOL
# 80  3.996541e-03    RPHENOX
# 81  1.000000e-11  RPHENOXM2
# 82  3.202143e-02    SYNAPYL
# 83  5.695688e-06      VADIO
# 84  5.195152e-04    VADIOM2
# 85  4.466498e-04  VCOUMARYL
# 86  2.128118e-03       VKET
# 87  2.058864e-02      VKETD
# 88  3.075704e-01    VKETDM2
# 89  3.846540e-05     VKETM2
# 90  7.419203e-03     VMGUAI
# 91  7.316815e-02    VPHENOL
# 92  6.603805e-02   VSYNAPYL
#
# [93 rows x 2 columns]

# %%
results_comparison = pd.DataFrame()
results_comparison['species'] = results['species']
results_comparison['ddasac'] = ddasac_resort['ddasac']
#LSODA results and error%
results_comparison['LSODA'] = results['LSODA']
LSODA_error = (results_comparison['LSODA'].values - results_comparison['ddasac'].values.astype(np.float))/results_comparison['ddasac'].values.astype(float)
LSODA_errlist = []
for i in LSODA_error:
    percent = "{0:.2f}%".format(i * 100)
    LSODA_errlist.append(percent)
results_comparison['LSODA_error'] = LSODA_errlist
#VODE results and error%
results_comparison['VODE'] = results['VODE']
VODE_error = (results_comparison['VODE'].values - results_comparison['ddasac'].values.astype(np.float))/results_comparison['ddasac'].values.astype(float)
VODE_errlist = []
for i in VODE_error:
    percent = "{0:.2f}%".format(i * 100)
    VODE_errlist.append(percent)
results_comparison['VODE_error'] = VODE_errlist
#VODE_new results and error%
results_comparison['VODE_new'] = results['VODE_new']
VODE_new_error = (results_comparison['VODE_new'].values - results_comparison['ddasac'].values.astype(np.float))/results_comparison['ddasac'].values.astype(float)
VODE_new_errlist = []
for i in VODE_new_error:
    percent = "{0:.2f}%".format(i * 100)
    VODE_new_errlist.append(percent)
results_comparison['VODE_new_error'] = VODE_new_errlist

results_comparison.to_csv('results_comparison.csv',index = False)
results_comparison
# Out:
#       species        ddasac         LSODA LSODA_error          VODE  \
# 0        ADIO  1.000000e-11  1.000000e-11       0.00%  1.000000e-11
# 1      ADIOM2  1.000000e-11  1.000000e-11       0.00%  1.000000e-11
# 2        ALD3  3.966974e-01  3.968274e-01       0.03%  3.968274e-01
# 3       C10H2  5.512506e-04  5.394858e-04      -2.13%  5.394859e-04
# 4     C10H2M2  2.281646e-03  3.744611e-03      64.12%  3.744613e-03
# 5     C10H2M4  3.740217e-02  2.716637e-02     -27.37%  2.716638e-02
# 6        C2H6  1.924486e-02  2.071977e-02       7.66%  2.071977e-02
# 7       C3H4O  5.354366e-04  1.226960e-03     129.15%  1.226959e-03
# 8      C3H4O2  1.651874e-01  1.784503e-01       8.03%  1.784504e-01
# 9        C3H6  5.248976e-02  5.235927e-02      -0.25%  5.235928e-02
# 10     C3H6O2  2.007737e-02  1.779422e-02     -11.37%  1.779422e-02
# 11     C3H8O2  2.273146e-04  2.096811e-03     822.43%  2.096812e-03
# 12      CH2CO  1.416971e+00  1.416971e+00       0.00%  1.416971e+00
# 13     CH3CHO  1.826846e-01  2.518667e-01      37.87%  2.518668e-01
# 14      CH3OH  6.018294e-01  7.687014e-01      27.73%  7.687013e-01
# 15        CH4  3.084947e-02  8.058968e-03     -73.88%  8.058975e-03
# 90     VMGUAI  7.419203e-03  7.342253e-03      -1.04%  7.342254e-03
# 91    VPHENOL  7.316815e-02  9.997323e-02      36.63%  9.997328e-02
# 92   VSYNAPYL  6.603805e-02  4.562040e-02     -30.92%  4.562041e-02
#
#    VODE_error      VODE_new VODE_new_error
# 0       0.00%  1.000000e-11          0.00%
# 1       0.00%  1.000000e-11          0.00%
# 2       0.03%  3.968274e-01          0.03%
# 3      -2.13%  5.394859e-04         -2.13%
# 4      64.12%  3.744612e-03         64.12%
# 5     -27.37%  2.716638e-02        -27.37%
# 6       7.66%  2.071977e-02          7.66%
# 7     129.15%  1.226959e-03        129.15%
# 8       8.03%  1.784504e-01          8.03%
# 9      -0.25%  5.235928e-02         -0.25%
# 10    -11.37%  1.779422e-02        -11.37%
# 11    822.43%  2.096812e-03        822.43%
# 12      0.00%  1.416971e+00          0.00%
# 13     37.87%  2.518668e-01         37.87%
# 14     27.73%  7.687013e-01         27.73%
# 15    -73.88%  8.058973e-03        -73.88%
# 16      9.40%  1.567157e+00          9.40%
# 17     20.97%  9.644098e-02         20.97%
# 18      3.61%  4.644188e-01          3.61%
# 19    -56.63%  6.795007e-03        -56.63%
# 20     -4.65%  5.083571e-02         -4.65%
# 21     -2.56%  3.025562e+00         -2.56%
# 22      0.45%  2.427879e+00          0.45%
# 23     -2.96%  3.320000e-08         -2.96%
# 24    -23.62%  5.964792e-01        -23.62%
# 25    -33.44%  2.760752e-02        -33.44%
# 26      0.00%  1.000000e-11          0.00%
# 27     -2.91%  3.320000e-08         -2.91%
# 28     -0.00%  2.476434e-04          0.00%
# 29      0.00%  1.000000e-11          0.00%
# ..        ...           ...            ...
# 63      0.00%  1.000000e-11          0.00%
# 64      0.00%  1.000000e-11          0.00%
# 65      0.00%  1.000000e-11          0.00%
# 66    144.46%  1.389090e-05        144.46%
# 67     61.04%  6.400000e-09         61.04%
# 68      0.00%  1.000000e-11          0.00%
# 69    -52.46%  2.020200e-06        -52.46%
# 70     -6.68%  2.161850e-05         -6.68%
# 71     -0.34%  1.120000e-08         -0.34%
# 72      0.00%  1.000000e-11          0.00%
# 73      0.17%  1.680000e-08          0.17%
# 74      0.18%  8.365000e-07          0.18%
# 75      0.00%  1.000000e-11          0.00%
# 76      0.00%  1.000000e-11          0.00%
# 77      0.00%  1.000000e-11          0.00%
# 78      0.00%  1.000000e-11          0.00%
# 79     24.62%  6.735860e-05         24.62%
# 80    -58.50%  1.658764e-03        -58.50%
# 81      0.00%  1.000000e-11          0.00%
# 82    -45.40%  1.748431e-02        -45.40%
# 83    -81.61%  1.047600e-06        -81.61%
# 84     -2.92%  5.043548e-04         -2.92%
# 85    -51.05%  2.186491e-04        -51.05%
# 86    -49.15%  1.082143e-03        -49.15%
# 87    -12.50%  1.801577e-02        -12.50%
# 88    -15.11%  2.610818e-01        -15.11%
# 89     -6.53%  3.595380e-05         -6.53%
# 90     -1.04%  7.342254e-03         -1.04%
# 91     36.63%  9.997327e-02         36.63%
# 92    -30.92%  4.562041e-02        -30.92%
#
# [93 rows x 8 columns]

# %%
results_comparison[results_comparison['ddasac'] > 1e-2]
# Out:
#      species    ddasac     LSODA LSODA_error      VODE VODE_error  VODE_new  \
# 2       ALD3  0.396697  0.396827       0.03%  0.396827      0.03%  0.396827
# 5    C10H2M4  0.037402  0.027166     -27.37%  0.027166    -27.37%  0.027166
# 6       C2H6  0.019245  0.020720       7.66%  0.020720      7.66%  0.020720
# 8     C3H4O2  0.165187  0.178450       8.03%  0.178450      8.03%  0.178450
# 9       C3H6  0.052490  0.052359      -0.25%  0.052359     -0.25%  0.052359
# 10    C3H6O2  0.020077  0.017794     -11.37%  0.017794    -11.37%  0.017794
# 12     CH2CO  1.416971  1.416971       0.00%  1.416971      0.00%  1.416971
# 13    CH3CHO  0.182685  0.251867      37.87%  0.251867     37.87%  0.251867
# 14     CH3OH  0.601829  0.768701      27.73%  0.768701     27.73%  0.768701
# 15       CH4  0.030849  0.008059     -73.88%  0.008059    -73.88%  0.008059
# 16      CHAR  1.432492  1.567157       9.40%  1.567157      9.40%  1.567157
# 17        CO  0.079725  0.096441      20.97%  0.096441     20.97%  0.096441
# 18       CO2  0.448259  0.464419       3.60%  0.464419      3.61%  0.464419
# 19  COUMARYL  0.015667  0.006795     -56.63%  0.006795    -56.63%  0.006795
# 20      ETOH  0.053313  0.050836      -4.65%  0.050836     -4.65%  0.050836
# 21        H2  3.104976  3.025562      -2.56%  3.025562     -2.56%  3.025562
# 22       H2O  2.416953  2.427879       0.45%  2.427879      0.45%  2.427879
# 24      KETD  0.780974  0.596479     -23.62%  0.596479    -23.62%  0.596479
# 25    KETDM2  0.041478  0.027608     -33.44%  0.027608    -33.44%  0.027608
# 32     MGUAI  0.011955  0.011831      -1.04%  0.011831     -1.04%  0.011831
# 36     PC2H2  0.630741  0.909904      44.26%  0.909904     44.26%  0.909904
# 38     PCH2P  0.196309  0.208547       6.23%  0.208547      6.23%  0.208547
# 42     PCHP2  0.153611  0.153411      -0.13%  0.153411     -0.13%  0.153411
# 43      PCOH  1.531473  1.859883      21.44%  1.859883     21.44%  1.859883
# 45      PCOS  2.450485  2.580176       5.29%  2.580176      5.29%  2.580176
# 48       PH2  2.024939  2.601500      28.47%  2.601499     28.47%  2.601499
# 49    PHENOL  0.033040  0.045346      37.25%  0.045346     37.25%  0.045346
# 82   SYNAPYL  0.032021  0.017484     -45.40%  0.017484    -45.40%  0.017484
# 87     VKETD  0.020589  0.018016     -12.50%  0.018016    -12.50%  0.018016
# 88   VKETDM2  0.307570  0.261082     -15.11%  0.261082    -15.11%  0.261082
# 91   VPHENOL  0.073168  0.099973      36.63%  0.099973     36.63%  0.099973
# 92  VSYNAPYL  0.066038  0.045620     -30.92%  0.045620    -30.92%  0.045620
#
#    VODE_new_error
# 2           0.03%
# 5         -27.37%
# 6           7.66%
# 8           8.03%
# 9          -0.25%
# 10        -11.37%
# 12          0.00%
# 13         37.87%
# 14         27.73%
# 15        -73.88%
# 16          9.40%
# 17         20.97%
# 18          3.61%
# 19        -56.63%
# 20         -4.65%
# 21         -2.56%
# 22          0.45%
# 24        -23.62%
# 25        -33.44%
# 32         -1.04%
# 36         44.26%
# 38          6.23%
# 42         -0.13%
# 43         21.44%
# 45          5.29%
# 48         28.47%
# 49         37.25%
# 82        -45.40%
# 87        -12.50%
# 88        -15.11%
# 91         36.63%
# 92        -30.92%
