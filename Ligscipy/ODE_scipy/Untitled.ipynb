# %%
with open('sol_heating_Pseudotsuga_menziesii.dat', 'r') as f:
    run_time = f.readlines()[-2]

# %%
run_time.split()
# Out:
# ['175.92592592592592',
#  '773.15',
#  '9.46536726723e-16',
#  '-1.70681106073e-115',
#  '0.222755541318',
#  '0.000426121553641',
#  '0.00251104263559',
#  '0.0194998850162',
#  '0.0185528526882',
#  '0.00221223449948',
#  '0.16535058201',
#  '0.0343089848408',
#  '0.0194599759591',
#  '0.0013672215921',
#  '1.6959204387',
#  '0.157852857537',
#  '0.698753064787',
#  '0.00607087328838',
#  '1.65402034665',
#  '0.086981261142',
#  '0.395976932237',
#  '0.0194253821212',
#  '0.0310554887797',
#  '3.09015191709',
#  '2.45712273926',
#  '4.22098240008e-08',
#  '0.718084775318',
#  '0.0177213189711',
#  '1.11527948458e-104',
#  '4.21907774342e-08',
#  '0.000296395213434',
#  '3.82580444744e-185',
#  '1.6004227038e-108',
#  '8.00144181897e-144',
#  '0.00833481710508',
#  '4.90584874037e-07',
#  '0.000839516679894',
#  '0.000445997116355',
#  '0.968137799675',
#  '3.27904588737e-12',
#  '0.222465263062',
#  '5.7540384356e-09',
#  '3.18184898428e-07',
#  '1.87184005385e-12',
# ...
